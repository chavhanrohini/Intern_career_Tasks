# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\dell\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from apscheduler.schedulers.background import BackgroundScheduler
from apscheduler.triggers.interval import IntervalTrigger
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Data exploration

# %%
# Function to scrap the camera details
def scrape_flipkart_camera_details():
    url="https://www.flipkart.com/search?q=camera&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_6_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_6_na_na_na&as-pos=4&as-type=RECENT&suggestionId=camera&requestId=c47f1865-d7a5-45c2-94d3-944b5486d93f&as-searchtext=camera"

# %%
url="https://www.flipkart.com/search?q=camera&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_6_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_6_na_na_na&as-pos=4&as-type=RECENT&suggestionId=camera&requestId=c47f1865-d7a5-45c2-94d3-944b5486d93f&as-searchtext=camera"

# %%
r=requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text)
camera_name=soup.select("._4rR01T")
camera_name=camera_name[:14]
all_names_of_camera=[]
for i in camera_name:
    all_names_of_camera.append(i.text)

# %%
all_names_of_camera
# Out:
# ['Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS II Lens',
#  'Canon EOS 3000D DSLR Camera 1 Camera Body, 18 - 55 mm Lens',
#  'Canon EOS 200D II DSLR Camera EF-S18-55mm IS STM',
#  'SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorless Camera Body with 28 - 70 mm Lens',
#  'FUJIFILM Instax Mini 11 Instant Camera',
#  'Canon EOS M50 Mark II Mirrorless Camera EF-M15-45mm is STM Lens',
#  'GoPro Hero 10 Waterproof with Front LCD and Touch Rear Screens, 5.3K60 Ultra HD Video, 1080p Live Stre...',
#  'Insta360 Action Camera X3 Sports and Action Camera',
#  'GoPro Hero11 Waterproof Sports and Action Camera',
#  'FUJIFILM Instax Treasure Box Mini 9 Instant Camera',
#  'SONY Alpha ILCE-6400 APS-C Mirrorless Camera Body Only Featuring Eye AF and 4K movie recording',
#  'FUJIFILM Instax Mini 11 Instant Camera',
#  'FUJIFILM Instax Treasure Box Mini 9 Instant Camera',
#  'FUJIFILM Instax Treasure Box Mini 11 Instant Camera']

# %%
price=soup.select("._30jeq3")
price = price[:14]
camera_price=[]
for i in price:
    camera_price.append(i.text)

# %%
camera_price
# Out:
# ['₹37,990',
#  '₹31,990',
#  '₹57,990',
#  '₹76,990',
#  '₹5,999',
#  '₹56,990',
#  '₹25,900',
#  '₹39,900',
#  '₹32,900',
#  '₹4,499',
#  '₹70,989',
#  '₹5,999',
#  '₹4,499',
#  '₹6,498']

# %%
features=soup.select(".rgWa7D")
features=features[:14]
camera_features=[]
for i in features:
    camera_features.append(i.text)

# %%
camera_features
# Out:
# ['Self-Timer, Type C and Mini HDMI, 9 point AF with 1 centre cross-type AF point, Standard ISO 100 - 6400 (expandable to 12 800), Wi-Fi / NFC supported, Full HD video with fully manual control and selectable frame rates, 1080p recording at 30p, optical viewfinder',
#  'Effective Pixels: 24.1 MP',
#  'Sensor Type: CMOS',
#  'WiFi Available',
#  '1080p recording at 30p',
#  '2 Year Warranty (1 year standard warranty + 1 year additional warranty from the date of purchase made by the customer.)',
#  'Self-Timer, Type C and Mini HDMI, 9 Auto Focus Points, 3x Optical Zoom, WiFi, Full HD, Video Recording at 1080 p on 30fps, APS-C CMOS sensor-which is 25 times larger than a typical Smartphone sensor.',
#  'Effective Pixels: 18 MP',
#  'Sensor Type: CMOS',
#  'WiFi Available',
#  'Full HD',
#  '2 Year Warranty (1 year standard warranty + 1 year additional warranty from the date of purchase made by the customer.)',
#  'Vari-angle Touch Screen LCD, Dual pixel CMOS AF, 3 975 selectable focus positions (Live View), EV -4 focusing limit, Eye Detection AF (One Shot & Servo AF ?Live View), OVF: 9 AF Points, Live View: 3 975 selectable focus positions, Live View: One-Shot AF & Servo AF, Touch Screen, Tilt Screen',
#  'Effective Pixels: 24.1 MP']

# %%
effective_pixels=soup.select(".rgWa7D:nth-child(2)")
effective_pixels=effective_pixels[:14]
effective_pixels_all_cameras=[]
for i in effective_pixels:
    effective_pixels_all_cameras.append(i.text)

# %%
effective_pixels_all_cameras
# Out:
# ['Effective Pixels: 24.1 MP',
#  'Effective Pixels: 18 MP',
#  'Effective Pixels: 24.1 MP',
#  'Effective Pixels: 24.3 MP',
#  'View Finder: Yes',
#  'Effective Pixels: 24.1 MP',
#  '5.3K, 4K',
#  'HDR',
#  '5.3K',
#  'View Finder: Yes',
#  'Effective Pixels: 24.2 MP',
#  'View Finder: Yes',
#  'View Finder: Yes',
#  'View Finder: Yes']

# %%
sensor_type=soup.select(".rgWa7D:nth-child(3)")
sensor_type=sensor_type[:14]
sensor_type_of_all_cameras=[]
for i in sensor_type:
    sensor_type_of_all_cameras.append(i.text)

# %%
sensor_type_of_all_cameras
# Out:
# ['Sensor Type: CMOS',
#  'Sensor Type: CMOS',
#  'Sensor Type: CMOS',
#  'Sensor Type: CMOS',
#  'Self Timer: No',
#  'Sensor Type: CMOS',
#  '1 year international + 1 year local India warranty. For 1 Year extended warranty please visit brand website',
#  '1 Year Manufacturer Warranty',
#  '1 year international + 1 year local India warranty. For 1 Year extended warranty please visit brand website',
#  'Self Timer: No',
#  'Sensor Type: CMOS',
#  'Self Timer: No',
#  'Self Timer: No',
#  'Self Timer: No']

# %%
resolution=soup.select(".rgWa7D:nth-child(5)")
resolution=resolution[:14]
resolutions=[]
for i in resolution:
    resolutions.append(i.text)

# %%
resolutions
# Out:
# ['1080p recording at 30p',
#  'Full HD',
#  'Full HD',
#  'Full HD',
#  'Built-in Flash',
#  'MP4',
#  'Built-in Flash',
#  'NTSC/PAL',
#  'Built-in Flash',
#  'Built-in Flash',
#  'Built-in Flash',
#  'Built-in Flash',
#  'Built-in Flash',
#  'Built-in Flash']

# %% [markdown]
# warranty=soup.select(".rgWa7D:nth-child(6)")
# warranty=warranty[:14]
# warranties=[]
# for i in warranty:
#     warranties.append(i.text)

# %% [markdown]
# # DataFrame Creation

# %%
import pandas as pd

camera_dataset = pd.DataFrame({'camera_name': camera_name})

# %%
# Ensure lengths are the same
max_length = max(len(camera_name), len(price), len(features), len(effective_pixels), len(sensor_type), len(resolution))

# Create Series with NaN values and set common index
camera_name = pd.Series(camera_name, index=range(max_length))
price = pd.Series(price, index=range(max_length))
features = pd.Series(features, index=range(max_length))
effective_pixels = pd.Series(effective_pixels, index=range(max_length))
sensor_type = pd.Series(sensor_type, index=range(max_length))
resolution = pd.Series(resolution, index=range(max_length))

# Create DataFrame by concatenating Series
camera_dataset = pd.DataFrame({
    'camera_name': camera_name,
    'price': price,
    'features': features, 
    'effective_pixels': effective_pixels,
    'sensor_type': sensor_type,
    'resolution': resolution
})

# %%
camera_dataset
# Out:
#                                           camera_name      price  \
# 0   [Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS...  [₹37,990]
# 1   [Canon EOS 3000D DSLR Camera 1 Camera Body, 18...  [₹31,990]
# 2   [Canon EOS 200D II DSLR Camera EF-S18-55mm IS ...  [₹57,990]
# 3   [SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirror...  [₹76,990]
# 4            [FUJIFILM Instax Mini 11 Instant Camera]   [₹5,999]
# 5   [Canon EOS M50 Mark II Mirrorless Camera EF-M1...  [₹56,990]
# 6   [GoPro Hero 10 Waterproof with Front LCD and T...  [₹25,900]
# 7   [Insta360 Action Camera X3 Sports and Action C...  [₹39,900]
# 8   [GoPro Hero11 Waterproof Sports and Action Cam...  [₹32,900]
# 9   [FUJIFILM Instax Treasure Box Mini 9 Instant C...   [₹4,499]
# 10  [SONY Alpha ILCE-6400 APS-C Mirrorless Camera ...  [₹70,989]
# 11           [FUJIFILM Instax Mini 11 Instant Camera]   [₹5,999]
# 12  [FUJIFILM Instax Treasure Box Mini 9 Instant C...   [₹4,499]
# 13  [FUJIFILM Instax Treasure Box Mini 11 Instant ...   [₹6,498]
#
#                                              features  \
# 0   [Self-Timer, Type C and Mini HDMI, 9 point AF ...
# 1                         [Effective Pixels: 24.1 MP]
# 2                                 [Sensor Type: CMOS]
# 3                                    [WiFi Available]
# 4                            [1080p recording at 30p]
# 5   [2 Year Warranty (1 year standard warranty + 1...
# 6   [Self-Timer, Type C and Mini HDMI, 9 Auto Focu...
# 7                           [Effective Pixels: 18 MP]
# 8                                 [Sensor Type: CMOS]
# 9                                    [WiFi Available]
# 10                                          [Full HD]
# 11  [2 Year Warranty (1 year standard warranty + 1...
# 12  [Vari-angle Touch Screen LCD, Dual pixel CMOS ...
# 13                        [Effective Pixels: 24.1 MP]
#
#                effective_pixels  \
# 0   [Effective Pixels: 24.1 MP]
# 1     [Effective Pixels: 18 MP]
# 2   [Effective Pixels: 24.1 MP]
# 3   [Effective Pixels: 24.3 MP]
# 4            [View Finder: Yes]
# 5   [Effective Pixels: 24.1 MP]
# 6                    [5.3K, 4K]
# 7                         [HDR]
# 8                        [5.3K]
# 9            [View Finder: Yes]
# 10  [Effective Pixels: 24.2 MP]
# 11           [View Finder: Yes]
# 12           [View Finder: Yes]
# 13           [View Finder: Yes]
#
#                                           sensor_type  \
# 0                                 [Sensor Type: CMOS]
# 1                                 [Sensor Type: CMOS]
# 2                                 [Sensor Type: CMOS]
# 3                                 [Sensor Type: CMOS]
# 4                                    [Self Timer: No]
# 5                                 [Sensor Type: CMOS]
# 6   [1 year international + 1 year local India war...
# 7                      [1 Year Manufacturer Warranty]
# 8   [1 year international + 1 year local India war...
# 9                                    [Self Timer: No]
# 10                                [Sensor Type: CMOS]
# 11                                   [Self Timer: No]
# 12                                   [Self Timer: No]
# 13                                   [Self Timer: No]
#
#                   resolution
# 0   [1080p recording at 30p]
# 1                  [Full HD]
# 2                  [Full HD]
# 3                  [Full HD]
# 4           [Built-in Flash]
# 5                      [MP4]
# 6           [Built-in Flash]
# 7                 [NTSC/PAL]
# 8           [Built-in Flash]
# 9           [Built-in Flash]
# 10          [Built-in Flash]
# 11          [Built-in Flash]
# 12          [Built-in Flash]
# 13          [Built-in Flash]

# %% [markdown]
# # Excel file creation

# %%
datatoexcel=pd.ExcelWriter("Cameraflip.xlsx",engine='xlsxwriter')

# %%
camera_dataset.to_excel(datatoexcel, sheet_name='sheet1')

# %%
datatoexcel.save()

# %% [markdown]
# # Data cleaning and Organization

# %%
if __name__ == '__main__':
    camera_dataset = pd.read_excel('Cameraflip.xlsx')
    print(camera_dataset)
    print(type(camera_dataset))

camera_dataset['features']=camera_dataset['features'].str.replace(r'\W', "")
print(camera_dataset)
# Out:
#     Unnamed: 0                                        camera_name  \
# 0            0  <div class="_4rR01T">Canon EOS 1500D DSLR Came...
# 1            1  <div class="_4rR01T">Canon EOS 3000D DSLR Came...
# 2            2  <div class="_4rR01T">Canon EOS 200D II DSLR Ca...
# 3            3  <div class="_4rR01T">SONY Alpha Full Frame ILC...
# 4            4  <div class="_4rR01T">FUJIFILM Instax Mini 11 I...
# 5            5  <div class="_4rR01T">Canon EOS M50 Mark II Mir...
# 6            6  <div class="_4rR01T">GoPro Hero 10 Waterproof ...
# 7            7  <div class="_4rR01T">Insta360 Action Camera X3...
# 8            8  <div class="_4rR01T">GoPro Hero11 Waterproof S...
# 9            9  <div class="_4rR01T">FUJIFILM Instax Treasure ...
# 10          10  <div class="_4rR01T">SONY Alpha ILCE-6400 APS-...
# 11          11  <div class="_4rR01T">FUJIFILM Instax Mini 11 I...
# 12          12  <div class="_4rR01T">FUJIFILM Instax Treasure ...
# 13          13  <div class="_4rR01T">FUJIFILM Instax Treasure ...
#
#                                          price  \
# 0   <div class="_30jeq3 _1_WHN1">₹37,990</div>
# 1   <div class="_30jeq3 _1_WHN1">₹31,990</div>
# 2   <div class="_30jeq3 _1_WHN1">₹57,990</div>
# 3   <div class="_30jeq3 _1_WHN1">₹76,990</div>
# 4    <div class="_30jeq3 _1_WHN1">₹5,999</div>
# 5   <div class="_30jeq3 _1_WHN1">₹56,990</div>
# 6   <div class="_30jeq3 _1_WHN1">₹25,900</div>
# 7   <div class="_30jeq3 _1_WHN1">₹39,900</div>
# 8   <div class="_30jeq3 _1_WHN1">₹32,900</div>
# 9    <div class="_30jeq3 _1_WHN1">₹4,499</div>
# 10  <div class="_30jeq3 _1_WHN1">₹70,989</div>
# 11   <div class="_30jeq3 _1_WHN1">₹5,999</div>
# 12   <div class="_30jeq3 _1_WHN1">₹4,499</div>
# 13   <div class="_30jeq3 _1_WHN1">₹6,498</div>
#
#                                              features  \
# 0   <li class="rgWa7D">Self-Timer, Type C and Mini...
# 1   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 2           <li class="rgWa7D">Sensor Type: CMOS</li>
# 3              <li class="rgWa7D">WiFi Available</li>
# 4      <li class="rgWa7D">1080p recording at 30p</li>
# 5   <li class="rgWa7D">2 Year Warranty (1 year sta...
# 6   <li class="rgWa7D">Self-Timer, Type C and Mini...
# 7     <li class="rgWa7D">Effective Pixels: 18 MP</li>
# 8           <li class="rgWa7D">Sensor Type: CMOS</li>
# 9              <li class="rgWa7D">WiFi Available</li>
# 10                    <li class="rgWa7D">Full HD</li>
# 11  <li class="rgWa7D">2 Year Warranty (1 year sta...
# 12  <li class="rgWa7D">Vari-angle Touch Screen LCD...
# 13  <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
#
#                                      effective_pixels  \
# 0   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 1     <li class="rgWa7D">Effective Pixels: 18 MP</li>
# 2   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 3   <li class="rgWa7D">Effective Pixels: 24.3 MP</li>
# 4            <li class="rgWa7D">View Finder: Yes</li>
# 5   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 6                    <li class="rgWa7D">5.3K, 4K</li>
# 7                         <li class="rgWa7D">HDR</li>
# 8                        <li class="rgWa7D">5.3K</li>
# 9            <li class="rgWa7D">View Finder: Yes</li>
# 10  <li class="rgWa7D">Effective Pixels: 24.2 MP</li>
# 11           <li class="rgWa7D">View Finder: Yes</li>
# 12           <li class="rgWa7D">View Finder: Yes</li>
# 13           <li class="rgWa7D">View Finder: Yes</li>
#
#                                           sensor_type  \
# 0           <li class="rgWa7D">Sensor Type: CMOS</li>
# 1           <li class="rgWa7D">Sensor Type: CMOS</li>
# 2           <li class="rgWa7D">Sensor Type: CMOS</li>
# 3           <li class="rgWa7D">Sensor Type: CMOS</li>
# 4              <li class="rgWa7D">Self Timer: No</li>
# 5           <li class="rgWa7D">Sensor Type: CMOS</li>
# 6   <li class="rgWa7D">1 year international + 1 ye...
# 7   <li class="rgWa7D">1 Year Manufacturer Warrant...
# 8   <li class="rgWa7D">1 year international + 1 ye...
# 9              <li class="rgWa7D">Self Timer: No</li>
# 10          <li class="rgWa7D">Sensor Type: CMOS</li>
# 11             <li class="rgWa7D">Self Timer: No</li>
# 12             <li class="rgWa7D">Self Timer: No</li>
# 13             <li class="rgWa7D">Self Timer: No</li>
#
#                                         resolution
# 0   <li class="rgWa7D">1080p recording at 30p</li>
# 1                  <li class="rgWa7D">Full HD</li>
# 2                  <li class="rgWa7D">Full HD</li>
# 3                  <li class="rgWa7D">Full HD</li>
# 4           <li class="rgWa7D">Built-in Flash</li>
# 5                      <li class="rgWa7D">MP4</li>
# 6           <li class="rgWa7D">Built-in Flash</li>
# 7                 <li class="rgWa7D">NTSC/PAL</li>
# 8           <li class="rgWa7D">Built-in Flash</li>
# 9           <li class="rgWa7D">Built-in Flash</li>
# 10          <li class="rgWa7D">Built-in Flash</li>
# 11          <li class="rgWa7D">Built-in Flash</li>
# 12          <li class="rgWa7D">Built-in Flash</li>
# 13          <li class="rgWa7D">Built-in Flash</li>
# <class 'pandas.core.frame.DataFrame'>
#     Unnamed: 0                                        camera_name  \
# 0            0  <div class="_4rR01T">Canon EOS 1500D DSLR Came...
# 1            1  <div class="_4rR01T">Canon EOS 3000D DSLR Came...
# 2            2  <div class="_4rR01T">Canon EOS 200D II DSLR Ca...
# 3            3  <div class="_4rR01T">SONY Alpha Full Frame ILC...
# 4            4  <div class="_4rR01T">FUJIFILM Instax Mini 11 I...
# 5            5  <div class="_4rR01T">Canon EOS M50 Mark II Mir...
# 6            6  <div class="_4rR01T">GoPro Hero 10 Waterproof ...
# 7            7  <div class="_4rR01T">Insta360 Action Camera X3...
# 8            8  <div class="_4rR01T">GoPro Hero11 Waterproof S...
# 9            9  <div class="_4rR01T">FUJIFILM Instax Treasure ...
# 10          10  <div class="_4rR01T">SONY Alpha ILCE-6400 APS-...
# 11          11  <div class="_4rR01T">FUJIFILM Instax Mini 11 I...
# 12          12  <div class="_4rR01T">FUJIFILM Instax Treasure ...
# 13          13  <div class="_4rR01T">FUJIFILM Instax Treasure ...
#
#                                          price  \
# 0   <div class="_30jeq3 _1_WHN1">₹37,990</div>
# 1   <div class="_30jeq3 _1_WHN1">₹31,990</div>
# 2   <div class="_30jeq3 _1_WHN1">₹57,990</div>
# 3   <div class="_30jeq3 _1_WHN1">₹76,990</div>
# 4    <div class="_30jeq3 _1_WHN1">₹5,999</div>
# 5   <div class="_30jeq3 _1_WHN1">₹56,990</div>
# 6   <div class="_30jeq3 _1_WHN1">₹25,900</div>
# 7   <div class="_30jeq3 _1_WHN1">₹39,900</div>
# 8   <div class="_30jeq3 _1_WHN1">₹32,900</div>
# 9    <div class="_30jeq3 _1_WHN1">₹4,499</div>
# 10  <div class="_30jeq3 _1_WHN1">₹70,989</div>
# 11   <div class="_30jeq3 _1_WHN1">₹5,999</div>
# 12   <div class="_30jeq3 _1_WHN1">₹4,499</div>
# 13   <div class="_30jeq3 _1_WHN1">₹6,498</div>
#
#                                              features  \
# 0   liclassrgWa7DSelfTimerTypeCandMiniHDMI9pointAF...
# 1                 liclassrgWa7DEffectivePixels241MPli
# 2                       liclassrgWa7DSensorTypeCMOSli
# 3                        liclassrgWa7DWiFiAvailableli
# 4                  liclassrgWa7D1080precordingat30pli
# 5   liclassrgWa7D2YearWarranty1yearstandardwarrant...
# 6   liclassrgWa7DSelfTimerTypeCandMiniHDMI9AutoFoc...
# 7                  liclassrgWa7DEffectivePixels18MPli
# 8                       liclassrgWa7DSensorTypeCMOSli
# 9                        liclassrgWa7DWiFiAvailableli
# 10                              liclassrgWa7DFullHDli
# 11  liclassrgWa7D2YearWarranty1yearstandardwarrant...
# 12  liclassrgWa7DVariangleTouchScreenLCDDualpixelC...
# 13                liclassrgWa7DEffectivePixels241MPli
#
#                                      effective_pixels  \
# 0   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 1     <li class="rgWa7D">Effective Pixels: 18 MP</li>
# 2   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 3   <li class="rgWa7D">Effective Pixels: 24.3 MP</li>
# 4            <li class="rgWa7D">View Finder: Yes</li>
# 5   <li class="rgWa7D">Effective Pixels: 24.1 MP</li>
# 6                    <li class="rgWa7D">5.3K, 4K</li>
# 7                         <li class="rgWa7D">HDR</li>
# 8                        <li class="rgWa7D">5.3K</li>
# 9            <li class="rgWa7D">View Finder: Yes</li>
# 10  <li class="rgWa7D">Effective Pixels: 24.2 MP</li>
# 11           <li class="rgWa7D">View Finder: Yes</li>
# 12           <li class="rgWa7D">View Finder: Yes</li>
# 13           <li class="rgWa7D">View Finder: Yes</li>
#
#                                           sensor_type  \
# 0           <li class="rgWa7D">Sensor Type: CMOS</li>
# 1           <li class="rgWa7D">Sensor Type: CMOS</li>
# 2           <li class="rgWa7D">Sensor Type: CMOS</li>
# 3           <li class="rgWa7D">Sensor Type: CMOS</li>
# 4              <li class="rgWa7D">Self Timer: No</li>
# 5           <li class="rgWa7D">Sensor Type: CMOS</li>
# 6   <li class="rgWa7D">1 year international + 1 ye...
# 7   <li class="rgWa7D">1 Year Manufacturer Warrant...
# 8   <li class="rgWa7D">1 year international + 1 ye...
# 9              <li class="rgWa7D">Self Timer: No</li>
# 10          <li class="rgWa7D">Sensor Type: CMOS</li>
# 11             <li class="rgWa7D">Self Timer: No</li>
# 12             <li class="rgWa7D">Self Timer: No</li>
# 13             <li class="rgWa7D">Self Timer: No</li>
#
#                                         resolution
# 0   <li class="rgWa7D">1080p recording at 30p</li>
# 1                  <li class="rgWa7D">Full HD</li>
# 2                  <li class="rgWa7D">Full HD</li>
# 3                  <li class="rgWa7D">Full HD</li>
# 4           <li class="rgWa7D">Built-in Flash</li>
# 5                      <li class="rgWa7D">MP4</li>
# 6           <li class="rgWa7D">Built-in Flash</li>
# 7                 <li class="rgWa7D">NTSC/PAL</li>
# 8           <li class="rgWa7D">Built-in Flash</li>
# 9           <li class="rgWa7D">Built-in Flash</li>
# 10          <li class="rgWa7D">Built-in Flash</li>
# 11          <li class="rgWa7D">Built-in Flash</li>
# 12          <li class="rgWa7D">Built-in Flash</li>
# 13          <li class="rgWa7D">Built-in Flash</li>
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17312\3834972556.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   camera_dataset['features']=camera_dataset['features'].str.replace(r'\W', "")

# %%
camera_dataset['camera_name']=camera_dataset['camera_name'].str.replace(r'\W', "", regex=True)
camera_dataset['effective_pixels']=camera_dataset['effective_pixels'].str.replace(r'\W', "", regex=True)
camera_dataset['sensor_type']=camera_dataset['sensor_type'].str.replace(r'\W', "", regex=True)
camera_dataset['resolution']=camera_dataset['resolution'].str.replace(r'\W', "", regex=True)
camera_dataset['camera_name']=camera_dataset['camera_name'].str.replace('divclass_4rR01T', "", regex=True)
camera_dataset['camera_name']=camera_dataset['camera_name'].str.replace('div', "", regex=True)
camera_dataset['price']=camera_dataset['price'].str.replace('<div class="_30jeq3 _1_WHN1">', "", regex=True)
camera_dataset['price']=camera_dataset['price'].str.replace('</div>', "",regex=True)
camera_dataset['price']=camera_dataset['price'].str.replace('₹', "",regex=True)
camera_dataset['features']=camera_dataset['features'].str.replace('liclassrgWa7D', "",regex=True)
camera_dataset['features']=camera_dataset['features'].str.replace('li', "",regex=True)
camera_dataset['effective_pixels']=camera_dataset['effective_pixels'].str.replace('liclassrgWa7DEffectivePixels', "",regex=True)
camera_dataset['effective_pixels']=camera_dataset['effective_pixels'].str.replace('li', "",regex=True)
camera_dataset['effective_pixels']=camera_dataset['effective_pixels'].str.replace('liclassrgWa7D', "",regex=True)
camera_dataset['effective_pixels']=camera_dataset['effective_pixels'].str.replace('classrgWa7D', "",regex=True)
camera_dataset['sensor_type']=camera_dataset['sensor_type'].str.replace('liclassrgWa7DSensorType', "",regex=True)
camera_dataset['sensor_type']=camera_dataset['sensor_type'].str.replace('li', "",regex=True)
camera_dataset['sensor_type']=camera_dataset['sensor_type'].str.replace('classrgWa7D', "",regex=True)
camera_dataset['resolution']=camera_dataset['resolution'].str.replace('liclassrgWa7D', "",regex=True)
print(camera_dataset)
# Out:
#     Unnamed: 0                                        camera_name   price  \
# 0            0          CanonEOS1500DDSLRCameraBody1855mmISIILens  37,990
# 1            1       CanonEOS3000DDSLRCamera1CameraBody1855mmLens  31,990
# 2            2             CanonEOS200DIIDSLRCameraEFS1855mmISSTM  57,990
# 3            3  SONYAlphaFullFrameILCE7M2KBQIN5MirrorlessCamer...  76,990
# 4            4                  FUJIFILMInstaxMini11InstantCamera   5,999
# 5            5  CanonEOSM50MarkIIMirrorlessCameraEFM1545mmisST...  56,990
# 6            6  GoProHero10WaterproofwithFrontLCDandTouchRearS...  25,900
# 7            7        Insta360ActionCameraX3SportsandActionCamera  39,900
# 8            8         GoProHero11WaterproofSportsandActionCamera  32,900
# 9            9        FUJIFILMInstaxTreasureBoxMini9InstantCamera   4,499
# 10          10  SONYAlphaILCE6400APSCMirrorlessCameraBodyOnlyF...  70,989
# 11          11                  FUJIFILMInstaxMini11InstantCamera   5,999
# 12          12        FUJIFILMInstaxTreasureBoxMini9InstantCamera   4,499
# 13          13       FUJIFILMInstaxTreasureBoxMini11InstantCamera   6,498
#
#                                              features effective_pixels  \
# 0   SelfTimerTypeCandMiniHDMI9pointAFwith1centrecr...            241MP
# 1                                EffectivePixels241MP             18MP
# 2                                      SensorTypeCMOS            241MP
# 3                                       WiFiAvailable            243MP
# 4                                 1080precordingat30p    ViewFinderYes
# 5   2YearWarranty1yearstandardwarranty1yearadditio...            241MP
# 6   SelfTimerTypeCandMiniHDMI9AutoFocusPoints3xOpt...            53K4K
# 7                                 EffectivePixels18MP              HDR
# 8                                      SensorTypeCMOS              53K
# 9                                       WiFiAvailable    ViewFinderYes
# 10                                             FullHD            242MP
# 11  2YearWarranty1yearstandardwarranty1yearadditio...    ViewFinderYes
# 12  VariangleTouchScreenLCDDualpixelCMOSAF3975sele...    ViewFinderYes
# 13                               EffectivePixels241MP    ViewFinderYes
#
#                                           sensor_type             resolution
# 0                                                CMOS  1080precordingat30pli
# 1                                                CMOS               FullHDli
# 2                                                CMOS               FullHDli
# 3                                                CMOS               FullHDli
# 4                                         SelfTimerNo         BuiltinFlashli
# 5                                                CMOS                  MP4li
# 6   1yearinternational1yearlocalIndiawarrantyFor1Y...         BuiltinFlashli
# 7                           1YearManufacturerWarranty              NTSCPALli
# 8   1yearinternational1yearlocalIndiawarrantyFor1Y...         BuiltinFlashli
# 9                                         SelfTimerNo         BuiltinFlashli
# 10                                               CMOS         BuiltinFlashli
# 11                                        SelfTimerNo         BuiltinFlashli
# 12                                        SelfTimerNo         BuiltinFlashli
# 13                                        SelfTimerNo         BuiltinFlashli

# %%
camera_dataset
# Out:
#     Unnamed: 0                                        camera_name   price  \
# 0            0          CanonEOS1500DDSLRCameraBody1855mmISIILens  37,990
# 1            1       CanonEOS3000DDSLRCamera1CameraBody1855mmLens  31,990
# 2            2             CanonEOS200DIIDSLRCameraEFS1855mmISSTM  57,990
# 3            3  SONYAlphaFullFrameILCE7M2KBQIN5MirrorlessCamer...  76,990
# 4            4                  FUJIFILMInstaxMini11InstantCamera   5,999
# 5            5  CanonEOSM50MarkIIMirrorlessCameraEFM1545mmisST...  56,990
# 6            6  GoProHero10WaterproofwithFrontLCDandTouchRearS...  25,900
# 7            7        Insta360ActionCameraX3SportsandActionCamera  39,900
# 8            8         GoProHero11WaterproofSportsandActionCamera  32,900
# 9            9        FUJIFILMInstaxTreasureBoxMini9InstantCamera   4,499
# 10          10  SONYAlphaILCE6400APSCMirrorlessCameraBodyOnlyF...  70,989
# 11          11                  FUJIFILMInstaxMini11InstantCamera   5,999
# 12          12        FUJIFILMInstaxTreasureBoxMini9InstantCamera   4,499
# 13          13       FUJIFILMInstaxTreasureBoxMini11InstantCamera   6,498
#
#                                              features effective_pixels  \
# 0   SelfTimerTypeCandMiniHDMI9pointAFwith1centrecr...            241MP
# 1                                EffectivePixels241MP             18MP
# 2                                      SensorTypeCMOS            241MP
# 3                                       WiFiAvailable            243MP
# 4                                 1080precordingat30p    ViewFinderYes
# 5   2YearWarranty1yearstandardwarranty1yearadditio...            241MP
# 6   SelfTimerTypeCandMiniHDMI9AutoFocusPoints3xOpt...            53K4K
# 7                                 EffectivePixels18MP              HDR
# 8                                      SensorTypeCMOS              53K
# 9                                       WiFiAvailable    ViewFinderYes
# 10                                             FullHD            242MP
# 11  2YearWarranty1yearstandardwarranty1yearadditio...    ViewFinderYes
# 12  VariangleTouchScreenLCDDualpixelCMOSAF3975sele...    ViewFinderYes
# 13                               EffectivePixels241MP    ViewFinderYes
#
#                                           sensor_type             resolution
# 0                                                CMOS  1080precordingat30pli
# 1                                                CMOS               FullHDli
# 2                                                CMOS               FullHDli
# 3                                                CMOS               FullHDli
# 4                                         SelfTimerNo         BuiltinFlashli
# 5                                                CMOS                  MP4li
# 6   1yearinternational1yearlocalIndiawarrantyFor1Y...         BuiltinFlashli
# 7                           1YearManufacturerWarranty              NTSCPALli
# 8   1yearinternational1yearlocalIndiawarrantyFor1Y...         BuiltinFlashli
# 9                                         SelfTimerNo         BuiltinFlashli
# 10                                               CMOS         BuiltinFlashli
# 11                                        SelfTimerNo         BuiltinFlashli
# 12                                        SelfTimerNo         BuiltinFlashli
# 13                                        SelfTimerNo         BuiltinFlashli

# %%
cleaned_data=camera_dataset

# %% [markdown]
# # Creating the Excel file of cleaned data

# %%
import pandas as pd
output_file_path = 'Cleaned_Cameraflip.xlsx'

# Save the DataFrame to an Excel file
cleaned_data.to_excel(output_file_path, index=False)

print(f"Cleaned data saved to '{output_file_path}'.")
# Out:
# Cleaned data saved to 'Cleaned_Cameraflip.xlsx'.

# %% [markdown]
# # Automation

# %%
pip install apscheduler
# Out:
# Requirement already satisfied: apscheduler in c:\users\dell\anaconda3\lib\site-packages (3.10.4)
# Requirement already satisfied: six>=1.4.0 in c:\users\dell\anaconda3\lib\site-packages (from apscheduler) (1.16.0)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from apscheduler) (5.2)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from apscheduler) (2021.3)
# Requirement already satisfied: tzdata in c:\users\dell\anaconda3\lib\site-packages (from tzlocal!=3.*,>=2.0->apscheduler) (2023.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Schedule the scraping job to run every hour
scheduler = BackgroundScheduler()
scheduler.add_job(scrape_flipkart_camera_details, trigger=IntervalTrigger(hours=1))

try:
    scheduler.start()
except (KeyboardInterrupt, SystemExit):
    pass

# %%
import pandas as pd

# Specify the file path
file_path = 'Cleaned_Cameraflip.xlsx'

# Load data using Pandas
cleaned_data = pd.read_excel(file_path)

# Display the first few rows of the loaded data
cleaned_data.head()
# Out:
#    Unnamed: 0                                        camera_name   price  \
# 0           0          CanonEOS1500DDSLRCameraBody1855mmISIILens  37,990
# 1           1       CanonEOS3000DDSLRCamera1CameraBody1855mmLens  31,990
# 2           2             CanonEOS200DIIDSLRCameraEFS1855mmISSTM  57,990
# 3           3  SONYAlphaFullFrameILCE7M2KBQIN5MirrorlessCamer...  76,990
# 4           4                  FUJIFILMInstaxMini11InstantCamera   5,999
#
#                                             features effective_pixels  \
# 0  SelfTimerTypeCandMiniHDMI9pointAFwith1centrecr...            241MP
# 1                               EffectivePixels241MP             18MP
# 2                                     SensorTypeCMOS            241MP
# 3                                      WiFiAvailable            243MP
# 4                                1080precordingat30p    ViewFinderYes
#
#    sensor_type             resolution
# 0         CMOS  1080precordingat30pli
# 1         CMOS               FullHDli
# 2         CMOS               FullHDli
# 3         CMOS               FullHDli
# 4  SelfTimerNo         BuiltinFlashli
